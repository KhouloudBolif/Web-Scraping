# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen

# %% [markdown]
# saisir le URL de la page que On veut scraper

# %%
url ="https://wuzzuf.net/explore"

# %%
client = urlopen(url)

# %% [markdown]
# RECUPERE code html de page

# %%
html = client.read()

# %%
html
# Out:
# b'<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">Login | WUZZUF</title>\n\n<meta data-react-helmet="true" name="description" content="Searching for jobs in Egypt? Wuzzuf helps you in your online job search to find Jobs in Egypt and Middle East. Choose the right job using our online recruitment services."/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employment in egypt, Egypt jobs, jobs vacancies, job vacanci
# ...

# %%
client.close()

# %% [markdown]
# on afiche la page html plus simple avec loutil html.parser

# %%
soup = bs(html , "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">Login | WUZZUF</title>
# ...

# %% [markdown]
# Retirer data

# %%
containers = soup.find_all("div", {"class":"css-19jjzw1 e1v1l3u10"})

# %%
len(containers)
# Out:
# 0
